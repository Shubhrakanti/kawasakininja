# %%
import pandas as pd


df = pd.read_csv("CNK Data.csv")


newdf = df[df["Loungers"] != 1.0]

for i,x in df.iterrows():
    print(x["State"])
# Out:
# Alaska
# Alabama
# Arkansas
# Arkansas
# Arkansas
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# Colorado
# Colorado
# Colorado
# Colorado
# Colorado
# Colorado
# Colorado
# Colorado
# Colorado
# Connecticut
# ...
